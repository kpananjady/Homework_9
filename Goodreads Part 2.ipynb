# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('scraped_books.csv')

# %%
df
# Out:
#                          author  rank  \
# 0               Margaret Atwood     1
# 1               Suzanne Collins     2
# 2   Mary Wollstonecraft Shelley     3
# 3             Madeleine L'Engle     4
# 4             Ursula K. Le Guin     5
# 5                 Veronica Roth     6
# 6               Suzanne Collins     7
# 7                    Lois Lowry     8
# 8             Octavia E. Butler     9
# 9             Ursula K. Le Guin    10
# 10              Margaret Atwood    11
# 11              Suzanne Collins    12
# 12           Audrey Niffenegger    13
# 13                Connie Willis    14
# 14            Ursula K. Le Guin    15
# 15                   Ann Leckie    16
# 16         Lois McMaster Bujold    17
# 17                Connie Willis    18
# 18           Mary Doria Russell    19
# 19               Anne McCaffrey    20
# 20            Octavia E. Butler    21
# 21         Lois McMaster Bujold    22
# 22         Lois McMaster Bujold    23
# ...

# %%
df['series'] = df.title.str.extract(r'[(]([A-Za-z ]*)\,?\s.\d[)]$')

# %%
df
# Out:
#                          author  rank  \
# 0               Margaret Atwood     1
# 1               Suzanne Collins     2
# 2   Mary Wollstonecraft Shelley     3
# 3             Madeleine L'Engle     4
# 4             Ursula K. Le Guin     5
# 5                 Veronica Roth     6
# 6               Suzanne Collins     7
# 7                    Lois Lowry     8
# 8             Octavia E. Butler     9
# 9             Ursula K. Le Guin    10
# 10              Margaret Atwood    11
# 11              Suzanne Collins    12
# 12           Audrey Niffenegger    13
# 13                Connie Willis    14
# 14            Ursula K. Le Guin    15
# 15                   Ann Leckie    16
# 16         Lois McMaster Bujold    17
# 17                Connie Willis    18
# 18           Mary Doria Russell    19
# 19               Anne McCaffrey    20
# 20            Octavia E. Butler    21
# 21         Lois McMaster Bujold    22
# 22         Lois McMaster Bujold    23
# ...

# %%
#df['title'] = df.title.str.extract(r'^([A-Za-z ]*)\b')

# %%
#df['title'] = df.title.str.extract(r'^([A-Za-z \'\?\!\.]*)[(]?')

# %%
df
# Out:
#                          author  rank  \
# 0               Margaret Atwood     1
# 1               Suzanne Collins     2
# 2   Mary Wollstonecraft Shelley     3
# 3             Madeleine L'Engle     4
# 4             Ursula K. Le Guin     5
# 5                 Veronica Roth     6
# 6               Suzanne Collins     7
# 7                    Lois Lowry     8
# 8             Octavia E. Butler     9
# 9             Ursula K. Le Guin    10
# 10              Margaret Atwood    11
# 11              Suzanne Collins    12
# 12           Audrey Niffenegger    13
# 13                Connie Willis    14
# 14            Ursula K. Le Guin    15
# 15                   Ann Leckie    16
# 16         Lois McMaster Bujold    17
# 17                Connie Willis    18
# 18           Mary Doria Russell    19
# 19               Anne McCaffrey    20
# 20            Octavia E. Butler    21
# 21         Lois McMaster Bujold    22
# 22         Lois McMaster Bujold    23
# ...

# %%
df.rating.str.extract(r'(\d\.\d\d)')
# Out:
#        0
# 0   4.09
# 1   4.33
# 2   3.78
# 3   4.01
# 4   4.06
# 5   4.21
# 6   4.29
# 7   4.12
# 8   4.23
# 9   4.21
# 10  4.01
# 11  4.03
# 12  3.96
# 13  4.03
# 14  4.11
# 15  3.98
# 16  4.11
# 17  4.13
# 18  4.17
# 19  4.10
# 20  4.16
# 21  4.29
# 22  4.31
# 23  3.84
# 24  4.05
# 25  4.45
# 26  3.68
# 27  3.91
# 28  4.06
# 29  4.09
# ..   ...
# 70  3.88
# 71  3.79
# 72  4.22
# 73  4.06
# 74  4.33
# 75  4.04
# 76  4.06
# 77  3.95
# 78  3.73
# 79  3.86
# 80  3.77
# 81  4.19
# 82  4.02
# 83  3.98
# 84  3.86
# 85  4.00
# 86  4.15
# 87  3.98
# 88  4.17
# 89  3.95
# 90  3.94
# 91  3.80
# 92  4.00
# 93  3.98
# 94  3.93
# 95  4.04
# 96  3.74
# 97  4.29
# 98  3.61
# 99  4.10
#
# [100 rows x 1 columns]

# %%
df['Number of ratings'] = df.rating.str.extract(r'—(.*)\bratings$')

# %%
df['rating'] = df.rating.str.extract(r'(\d\.\d\d)')

# %%
df
# Out:
#                          author  rank rating   score  \
# 0               Margaret Atwood     1   4.09  30,733
# 1               Suzanne Collins     2   4.33  28,553
# 2   Mary Wollstonecraft Shelley     3   3.78  21,909
# 3             Madeleine L'Engle     4   4.01  18,720
# 4             Ursula K. Le Guin     5   4.06  17,920
# 5                 Veronica Roth     6   4.21  13,326
# 6               Suzanne Collins     7   4.29  12,749
# 7                    Lois Lowry     8   4.12  12,399
# 8             Octavia E. Butler     9   4.23  11,070
# 9             Ursula K. Le Guin    10   4.21  10,731
# 10              Margaret Atwood    11   4.01  10,117
# 11              Suzanne Collins    12   4.03   9,807
# 12           Audrey Niffenegger    13   3.96   9,193
# 13                Connie Willis    14   4.03   8,935
# 14            Ursula K. Le Guin    15   4.11   7,775
# 15                   Ann Leckie    16   3.98   7,336
# 16         Lois McMaster Bujold    17   4.11   7,017
# ...

# %%
df['Number in series'] = df.title.str.extract(r'(.)[)]')

# %%
df['title'] = df.title.str.extract(r'^([A-Za-z \'\?\!\.]*)[(]?')

# %%
df
# Out:
#                          author  rank rating   score  \
# 0               Margaret Atwood     1   4.09  30,733
# 1               Suzanne Collins     2   4.33  28,553
# 2   Mary Wollstonecraft Shelley     3   3.78  21,909
# 3             Madeleine L'Engle     4   4.01  18,720
# 4             Ursula K. Le Guin     5   4.06  17,920
# 5                 Veronica Roth     6   4.21  13,326
# 6               Suzanne Collins     7   4.29  12,749
# 7                    Lois Lowry     8   4.12  12,399
# 8             Octavia E. Butler     9   4.23  11,070
# 9             Ursula K. Le Guin    10   4.21  10,731
# 10              Margaret Atwood    11   4.01  10,117
# 11              Suzanne Collins    12   4.03   9,807
# 12           Audrey Niffenegger    13   3.96   9,193
# 13                Connie Willis    14   4.03   8,935
# 14            Ursula K. Le Guin    15   4.11   7,775
# 15                   Ann Leckie    16   3.98   7,336
# 16         Lois McMaster Bujold    17   4.11   7,017
# ...
